# %% [markdown]
# # **"Speaker Diarization with WhisperX"**

# %% [markdown]
# ### The purpose of this notebook is to use the [WhisperX](https://github.com/m-bain/whisperx) library to perform speaker diarization on a given audio file.
#
# #### **Libraries/Repos Used:**
# - [WhisperX](https://github.com/m-bain/whisperx)
# - [Pyannote](https://github.com/pyannote/pyannote-audio)
# - [Hugging Face](https://huggingface.co/)
# - [Hugging Face Hub](https://huggingface.co/)
#
# #### **Work Flow:**
# - Load Audio
# - Transcribe using Whisper model
# - Chunk level transcriptions
# - For Word level Transcriptions (Aligning the words)
# - Speaker Diarization

# %% [markdown]
# # +_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+

# %% [markdown]
# ### 1. Install WhisperX

# %%
# !pip install --q git+https://github.com/m-bain/whisperx.git

# %% [markdown]
# ### 2. Import Libraries

# %%
import whisperx
import gc

# %% [markdown]
# ### 3. Set Parameters
# ##### compute_type: "float16" or "int8" (default: "float16", it will be faster in computation but slightly less accurate than "int8")

# %%
device = "cuda"
batch_size = 4
comput_type = "float16"

# %% [markdown]
# ## **4. Speech to text Transcription:**

# %% [markdown]
# ### Load Audio

# %%
audio_file = "/content/talk.mp3"

# %% [markdown]
# ### 1) Transcribe using Whisper model:

# %%
model = whisperx.load_model("large-v2", device, compute_type=comput_type)
# Out:
# model.bin:   0%|          | 0.00/3.09G [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/2.80k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.20M [00:00<?, ?B/s]
# vocabulary.txt:   0%|          | 0.00/460k [00:00<?, ?B/s]
# No language specified, language will be first be detected for each audio file (increases inference time).
# 100%|█████████████████████████████████████| 16.9M/16.9M [00:02<00:00, 7.94MiB/s]
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.5.4 to v2.4.0. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../root/.cache/torch/whisperx-vad-segmentation.bin`
# Model was trained with pyannote.audio 0.0.1, yours is 3.1.1. Bad things might happen unless you revert pyannote.audio to 0.x.
# Model was trained with torch 1.10.0+cu102, yours is 2.3.1+cu121. Bad things might happen unless you revert torch to 1.x.

# %% [markdown]
# ### Transcribe:

# %%
audio = whisperx.load_audio(audio_file)
result = model.transcribe(audio, batch_size=batch_size)
print(result["segments"]) # before alignment
# Out:
# Detected language: en (0.98) in first 30s of audio...
# [{'text': " What's that? I don't know where the question... I don't know where the song is. Well, can I ask you a question? The first one? Right. What is the worst thing about being young? Well, you get lots of homework. It's also pretty... It's... They're like in the middle. Like in school, like in the middle of bad and good.", 'start': 5.247, 'end': 32.944}, {'text': " What is the worst thing about being old? Not being able to do things that you could do when you were young. Like, you can't bend down and get stuff on the floor? Well, I can still do that. But the problem is your body gets a bit stiff. I know it hurts a lot when you try to get down when you are old. That's right, yes. You might get sick more often. Hopefully I don't. But that's the problem. Yeah, that's pretty bad. It is pretty bad.", 'start': 33.217, 'end': 63.097}, {'text': ' The only time I went to hospital is my mum to like get me born. Do you wish you were old? Maybe, like so I was old and I so I can like buy stuff for my own and have be and have been married but that would be eww. Do you wish you were young? Why?', 'start': 63.251, 'end': 89.599}, {'text': " Well, the problem about, the great thing about being young is you have more time. You have more time to do things. I could play games, which I did. I used to play cowboys and Indians. Yeah, that's what I play. Do you? Yeah. That's what I like about being young. I could use my imagination more. That's a sad story. You can't do that anymore. Well, I could be an older cowboy. I might do it yet. Will you fall in love?", 'start': 91.049, 'end': 120.333}, {'text': " And what will it be like? I don't know. Like, we'll have babies. It'll be, like, fun. I'll, like, have to change. Even though I'll have to change his diaper. It'll be fun. Ah. But what if he cries? Ah, well... I'll just sing, like, Ed Sheeran to him, like... Hmm? And who do you love now? Who do you love now? Um... Hmm? My mom. Your mom? Your dad?", 'start': 121.476, 'end': 150.691}, {'text': ' I like my family. Did you fall in love? What was it like? Yes. It was different for me. I fell in love late. And did you get married? No, unfortunately. My partner, she passed away. She died, unfortunately. That was a sad thing. Yeah, she got sick.', 'start': 151.015, 'end': 177.278}, {'text': " I'm gonna cry. No, no, no. Don't. No, no, no. No. Ah, no, no. These things happen, Sian. That's life. But... I have very good memories. Very good memories. And you live... A lot of the time, you live in your head with memories. You can remember all the good things, and that's the important thing.", 'start': 177.927, 'end': 198.712}, {'text': " Well, the advice I would give to you, Sean, is you don't have to be rich to be happy. Do the things you like doing that make you feel good. Because when you're happy yourself, everybody else is happy. Sean, do you have advice for Dad? To act normal, don't be silly, don't bully lots of people. The people I know in school, like my friend Alex in school,", 'start': 202.841, 'end': 230.35}, {'text': " Whenever he gets hurt, I hug him. He might not be able to work, but... No, that's good advice. And be yourself. Don't let other people tell you what you should be. Just be as you are. Isn't that true? Yeah. And I'm sure your life is going to be very successful. You have all the right things. You have all the right things to do. All your good friends. And keep those friends going. And keep life going. Oops. There you go.", 'start': 230.828, 'end': 260.691}]

# %% [markdown]
# ### Chunk level transcriptions:

# %%
result
# Out:
# {'segments': [{'text': " What's that? I don't know where the question... I don't know where the song is. Well, can I ask you a question? The first one? Right. What is the worst thing about being young? Well, you get lots of homework. It's also pretty... It's... They're like in the middle. Like in school, like in the middle of bad and good.",
#    'start': 5.247,
#    'end': 32.944},
#   {'text': " What is the worst thing about being old? Not being able to do things that you could do when you were young. Like, you can't bend down and get stuff on the floor? Well, I can still do that. But the problem is your body gets a bit stiff. I know it hurts a lot when you try to get down when you are old. That's right, yes. You might get sick more often. Hopefully I don't. But that's the problem. Yeah, that's pretty bad. It is pretty bad.",
#    'start': 33.217,
#    'end': 63.097},
#   {'text': ' The only time I went to hospital is my mum to like get me born. Do you wish you were old? Maybe, like so I was old and I so I can like buy stuff for my own and have be and have been married but that would be eww. Do you wish you were young? Why?',
#    'start': 63.251,
#    'end': 89.599},
#   {'text': " Well, the problem about, the great thing about being young is you have more time. You have more time to do things. I could play games, which I did. I used to play cowboys and Indians. Yeah, that's what I play. Do you? Yeah. That's what I like about being young. I could use my imagination more. That's a sad story. You can't do that anymore. Well, I could be an older cowboy. I might do it yet. Will you fall in love?",
#    'start': 91.049,
#    'end': 120.333},
#   {'text': " And what will it be like? I don't know. Like, we'll have babies. It'll be, like, fun. I'll, like, have to change. Even though I'll have to change his diaper. It'll be fun. Ah. But what if he cries? Ah, well... I'll just sing, like, Ed Sheeran to him, like... Hmm? And who do you love now? Who do you love now? Um... Hmm? My mom. Your mom? Your dad?",
#    'start': 121.476,
#    'end': 150.691},
#   {'text': ' I like my family. Did you fall in love? What was it like? Yes. It was different for me. I fell in love late. And did you get married? No, unfortunately. My partner, she passed away. She died, unfortunately. That was a sad thing. Yeah, she got sick.',
#    'start': 151.015,
#    'end': 177.278},
#   {'text': " I'm gonna cry. No, no, no. Don't. No, no, no. No. Ah, no, no. These things happen, Sian. That's life. But... I have very good memories. Very good memories. And you live... A lot of the time, you live in your head with memories. You can remember all the good things, and that's the important thing.",
#    'start': 177.927,
#    'end': 198.712},
#   {'text': " Well, the advice I would give to you, Sean, is you don't have to be rich to be happy. Do the things you like doing that make you feel good. Because when you're happy yourself, everybody else is happy. Sean, do you have advice for Dad? To act normal, don't be silly, don't bully lots of people. The people I know in school, like my friend Alex in school,",
#    'start': 202.841,
#    'end': 230.35},
#   {'text': " Whenever he gets hurt, I hug him. He might not be able to work, but... No, that's good advice. And be yourself. Don't let other people tell you what you should be. Just be as you are. Isn't that true? Yeah. And I'm sure your life is going to be very successful. You have all the right things. You have all the right things to do. All your good friends. And keep those friends going. And keep life going. Oops. There you go.",
#    'start': 230.828,
#    'end': 260.691}],
#  'language': 'en'}

# %% [markdown]
# ### 2) For Word level Transcriptions (Aligning the words)
#
# ##### Its a 2 step process. First transcribe audio using one model, then we use another model called align_model. align_model takes the results from the previous model and its language as input and it will return alignment model and corresponding metadata.

# %%
model_a, metadata = whisperx.load_align_model(language_code=result["language"], device=device)

result = whisperx.align(result["segments"], model_a, metadata, audio, device, return_char_alignments=False)
# we don't need alignment for each character, but for each word (hence return_char_alignments = FALSE)

print(result["segments"]) # after alignment
# Out:
# Downloading: "https://download.pytorch.org/torchaudio/models/wav2vec2_fairseq_base_ls960_asr_ls960.pth" to /root/.cache/torch/hub/checkpoints/wav2vec2_fairseq_base_ls960_asr_ls960.pth
# 100%|██████████| 360M/360M [00:01<00:00, 223MB/s]
# [{'start': 7.168, 'end': 7.568, 'text': " What's that?", 'words': [{'word': "What's", 'start': 7.168, 'end': 7.468, 'score': 0.296}, {'word': 'that?', 'start': 7.488, 'end': 7.568, 'score': 0.122}]}, {'start': 7.588, 'end': 10.69, 'text': "I don't know where the question... I don't know where the song is.", 'words': [{'word': 'I', 'start': 7.588, 'end': 7.608, 'score': 0.002}, {'word': "don't", 'start': 7.628, 'end': 7.769, 'score': 0.771}, {'word': 'know', 'start': 7.789, 'end': 7.929, 'score': 0.795}, {'word': 'where', 'start': 7.949, 'end': 8.149, 'score': 0.576}, {'word': 'the', 'start': 8.189, 'end': 8.349, 'score': 0.486}, {'word': 'question...', 'start': 8.369, 'end': 9.049, 'score': 0.75}, {'word': 'I', 'start': 9.51, 'end': 9.57, 'score': 0.383}, {'word': "don't", 'start': 9.61, 'end': 9.73, 'score': 0.271}, {'word': 'know', 'start': 9.75, 'end': 9.85, 'score': 0.162}, {'word': 'where', 'start': 9.89, 'end': 10.07, 'score': 0.531}, {'word': 'the', 'start': 10.09, 'end': 10.21, 'score': 0.122}, {'word': 'song', 'start': 10.23, 'end': 10.45, 'score': 0.65}, {'word': 'is.', 'start': 10.53, 'end': 10.69, 'score': 0.688}]}, {'start': 12.431, 'end': 13.592, 'text': 'Well, can I ask you a question?', 'words': [{'word': 'Well,', 'start': 12.431, 'end': 12.592, 'score': 0.483}, {'word': 'can', 'start': 12.612, 'end': 12.752, 'score': 0.282}, {'word': 'I', 'start': 12.772, 'end': 12.792, 'score': 0.092}, {'word': 'ask', 'start': 12.832, 'end': 13.012, 'score': 0.736}, {'word': 'you', 'start': 13.032, 'end': 13.132, 'score': 0.889}, {'word': 'a', 'start': 13.152, 'end': 13.172, 'score': 0.537}, {'word': 'question?', 'start': 13.192, 'end': 13.592, 'score': 0.67}]}, {'start': 13.632, 'end': 14.132, 'text': 'The first one?', 'words': [{'word': 'The', 'start': 13.632, 'end': 13.712, 'score': 0.781}, {'word': 'first', 'start': 13.732, 'end': 13.932, 'score': 0.877}, {'word': 'one?', 'start': 14.012, 'end': 14.132, 'score': 0.856}]}, {'start': 16.014, 'end': 16.294, 'text': 'Right.', 'words': [{'word': 'Right.', 'start': 16.014, 'end': 16.294, 'score': 0.841}]}, {'start': 17.374, 'end': 19.116, 'text': 'What is the worst thing about being young?', 'words': [{'word': 'What', 'start': 17.374, 'end': 17.515, 'score': 0.989}, {'word': 'is', 'start': 17.595, 'end': 17.695, 'score': 0.501}, {'word': 'the', 'start': 17.735, 'end': 17.835, 'score': 0.919}, {'word': 'worst', 'start': 17.935, 'end': 18.195, 'score': 0.915}, {'word': 'thing', 'start': 18.235, 'end': 18.395, 'score': 0.721}, {'word': 'about', 'start': 18.435, 'end': 18.635, 'score': 0.863}, {'word': 'being', 'start': 18.675, 'end': 18.875, 'score': 0.62}, {'word': 'young?', 'start': 18.895, 'end': 19.116, 'score': 0.36}]}, {'start': 20.656, 'end': 23.078, 'text': 'Well, you get lots of homework.', 'words': [{'word': 'Well,', 'start': 20.656, 'end': 20.977, 'score': 0.833}, {'word': 'you', 'start': 21.037, 'end': 21.217, 'score': 0.772}, {'word': 'get', 'start': 21.237, 'end': 21.457, 'score': 0.521}, {'word': 'lots', 'start': 21.617, 'end': 22.057, 'score': 0.899}, {'word': 'of', 'start': 22.157, 'end': 22.297, 'score': 0.83}, {'word': 'homework.', 'start': 22.358, 'end': 23.078, 'score': 0.897}]}, {'start': 23.999, 'end': 28.421, 'text': "It's also pretty... It's... They're like in the middle.", 'words': [{'word': "It's", 'start': 23.999, 'end': 24.139, 'score': 0.896}, {'word': 'also', 'start': 24.179, 'end': 24.499, 'score': 0.92}, {'word': 'pretty...', 'start': 24.599, 'end': 24.899, 'score': 0.78}, {'word': "It's...", 'start': 25.499, 'end': 25.62, 'score': 0.557}, {'word': "They're", 'start': 25.98, 'end': 26.14, 'score': 0.21}, {'word': 'like', 'start': 26.16, 'end': 26.42, 'score': 0.786}, {'word': 'in', 'start': 27.621, 'end': 27.721, 'score': 0.946}, {'word': 'the', 'start': 27.741, 'end': 27.961, 'score': 0.643}, {'word': 'middle.', 'start': 28.041, 'end': 28.421, 'score': 0.733}]}, {'start': 28.902, 'end': 32.784, 'text': 'Like in school, like in the middle of bad an ...

# %% [markdown]
# ## **5. Identify Multiple Speakers:**
#
# ##### Identify speakers and transcribe in such a way that a different ID is assigned to each individual speaker

# %%
audio_file = "/content/talk.mp3"

# %%
audio = whisperx.load_audio(audio_file)

# %% [markdown]
# ### Diarization model of Whisperx
#
#
# ##### Running this line for the first time will throw a pyannote error so you have to go to its github and login there to use it: [pyannote_link](https://github.com/pyannote/pyannote-audio)

# %%
diarize_model = whisperx.DiarizationPipeline(use_auth_token="YOUR_HUGGING_FACE_TOKEN", device=device)  # use your hugging face token key
# Out:
# pytorch_model.bin:   0%|          | 0.00/26.6M [00:00<?, ?B/s]
# config.yaml:   0%|          | 0.00/221 [00:00<?, ?B/s]

# %%
diarize_segments = diarize_model(audio, min_speakers=2, max_speakers=10)

# %%
diarize_segments
# Out:
#                                segment label     speaker       start  \
# 0    [ 00:00:02.538 -->  00:00:03.726]     A  SPEAKER_00    2.538200
# 1    [ 00:00:03.726 -->  00:00:04.711]     B  SPEAKER_01    3.726655
# 2    [ 00:00:04.711 -->  00:00:04.949]     C  SPEAKER_00    4.711375
# 3    [ 00:00:04.949 -->  00:00:05.000]     D  SPEAKER_01    4.949066
# 4    [ 00:00:05.152 -->  00:00:05.865]     E  SPEAKER_01    5.152801
# ..                                 ...   ...         ...         ...
# 101  [ 00:04:10.534 -->  00:04:14.032]    CX  SPEAKER_01  250.534805
# 102  [ 00:04:14.405 -->  00:04:15.560]    CY  SPEAKER_01  254.405772
# 103  [ 00:04:16.273 -->  00:04:18.005]    CZ  SPEAKER_01  256.273345
# 104  [ 00:04:18.412 -->  00:04:19.753]    DA  SPEAKER_01  258.412564
# 105  [ 00:04:20.280 -->  00:04:20.704]    DB  SPEAKER_01  260.280136
#
#             end
# 0      3.726655
# 1      4.711375
# 2      4.949066
# 3      5.000000
# 4      5.865874
# ..          ...
# 101  254.032258
# 102  255.560272
# 103  258.005093
# 104  259.753820
# 105  260.704584
#
# [106 rows x 5 columns]

# %% [markdown]
# ## **6. Combine the output of Speaker Identification and Speech Transcription**

# %%
result = whisperx.assign_word_speakers(diarize_segments, result)
print(diarize_segments)
print(result["segments"]) # segments are now assigned speaker IDs
# Out:
#                                segment label     speaker       start  \
# 0    [ 00:00:02.538 -->  00:00:03.726]     A  SPEAKER_00    2.538200
# 1    [ 00:00:03.726 -->  00:00:04.711]     B  SPEAKER_01    3.726655
# 2    [ 00:00:04.711 -->  00:00:04.949]     C  SPEAKER_00    4.711375
# 3    [ 00:00:04.949 -->  00:00:05.000]     D  SPEAKER_01    4.949066
# 4    [ 00:00:05.152 -->  00:00:05.865]     E  SPEAKER_01    5.152801
# ..                                 ...   ...         ...         ...
# 101  [ 00:04:10.534 -->  00:04:14.032]    CX  SPEAKER_01  250.534805
# 102  [ 00:04:14.405 -->  00:04:15.560]    CY  SPEAKER_01  254.405772
# 103  [ 00:04:16.273 -->  00:04:18.005]    CZ  SPEAKER_01  256.273345
# 104  [ 00:04:18.412 -->  00:04:19.753]    DA  SPEAKER_01  258.412564
# 105  [ 00:04:20.280 -->  00:04:20.704]    DB  SPEAKER_01  260.280136
#
#             end  intersection       union
# 0      3.726655   -256.804345  258.052800
# 1      4.711375   -255.819625  256.864345
# 2      4.949066   -255.581934  255.879625
# 3      5.000000   -255.531000  255.641934
# 4      5.865874   -254.665126  255.438199
# ..          ...           ...         ...
# 101  254.032258     -6.498742   10.056195
# 102  255.560272     -4.970728    6.185228
# 103  258.005093     -2.525907    4.317655
# 104  259.753820     -0.777180    2.178436
# 105  260.704584      0.060000    0.424448
#
# [106 rows x 7 columns]
# [{'start': 7.168, 'end': 7.568, 'text': " What's that?", 'words': [{'word': "What's", 'start': 7.168, 'end': 7.468, 'score': 0.296, 'speaker': 'SPEAKER_01'}, {'word': 'that?', 'start': 7.488, 'end': 7.568, 'score': 0.122, 'speaker': 'SPEAKER_00'}], 'speaker': 'SPEAKER_01'}, {'start': 7.588, 'end': 10.69, 'text': "I don't know where the question... I don't know where the song is.", 'words': [{'word': 'I', 'start': 7.588, 'end': 7.608, 'score': 0.002, 'speaker': 'SPEAKER_00'}, {'word': "don't", 'start': 7.628, 'end': 7.769, 'score': 0.771, 'speaker': 'SPEAKER_00'}, {'word': 'know', 'start': 7.789, 'end': 7.929, 'score': 0.795, 'speaker': 'SPEAKER_00'}, {'word': 'where', 'start': 7.949, 'end': 8.149, 'score': 0.576, 'speaker': 'SPEAKER_00'}, {'word': 'the', 'start': 8.189, 'end': 8.349, 'score': 0.486, 'speaker': 'SPEAKER_00'}, {'word': 'question...', 'start': 8.369, 'end': 9.049, 'score': 0.75, 'speaker': 'SPEAKER_00'}, {'word': 'I', 'start': 9.51, 'end': 9.57, 'score': 0.383, 'speaker': 'SPEAKER_00'}, {'word': "don't", 'start': 9.61, 'end': 9.73, 'score': 0.271, 'speaker': 'SPEAKER_00'}, {'word': 'know', 'start': 9.75, 'end': 9.85, 'score': 0.162, 'speaker': 'SPEAKER_00'}, {'word': 'where', 'start': 9.89, 'end': 10.07, 'score': 0.531, 'speaker': 'SPEAKER_00'}, {'word': 'the', 'start': 10.09, 'end': 10.21, 'score': 0.122, 'speaker': 'SPEAKER_00'}, {'word': 'song', 'start': 10.23, 'end': 10.45, 'score': 0.65, 'speaker': 'SPEAKER_00'}, {'word': 'is.', 'start': 10.53, 'end': 10.69, 'score': 0.688, 'speaker': 'SPEAKER_00'}], 'speaker': 'SPEAKER_00'}, {'start': 12.431, 'end': 13.592, 'text': 'Well, can I ask you a question?', 'words': [{'word': 'Well,', 'start': 12.431, 'end': 12.592, 'score': 0.483, 'speaker': 'SPEAKER_01'}, {'word': 'can', 'start': 12.612, 'end': 12.752, 'score': 0.282, 'speaker': 'SPEAKER_01'}, {'word': 'I', 'start': 12.772, 'end': 12.792, 'score': 0.092, 'speaker': 'SPEAKER_01'}, {'word': 'ask', 'start': 12.832, 'end': 13.012, 'score': 0.736, 'speaker': 'SPEAKER_01'}, {'word': 'you', 'start': 13.032, 'end': 13.132, 'score': 0.889, 'speaker': 'SPEAKER_01'}, {'word': 'a', 'start': 13.152, 'end': 13.172, 'score': 0.537, 'speaker': 'SPEAKER_01'}, {'word': 'question?', 'start': 13.192, 'end': 13.592, 'score': 0.67, 'speaker': 'SPEAKER_01'}], 'speaker': 'SPEAKER_01'}, {'start': 13.632, 'end': 14.132, 'text': 'The first one?', 'words': [{'word': 'The', 'start': 13.632, 'end': 13.712, 'score': 0.781, 'speaker': 'SPEAKER_01'}, {'word': 'first', 'start': 13.732, 'end': 13.932, 'score': 0.877, 'speaker': 'SPEAKER_01'}, {'word': 'one?', 'start': 14.012, 'end': 14.132, 'score': 0.856, 'speaker': 'SPEAKER_01'}], 'speaker': 'SPEAKER_01'}, {'start': 16.014, 'end': 16.294, 'text': 'Right.', 'words': [{'word': 'Right.', 'start': 16.014, 'end': 16.294, 'score': 0.841, 'speaker': 'SPEAKER_01'}], 'speaker': 'SPEAKER_01'}, {'start': 17.374, 'end': 19.116, 'text': 'What is the worst thing about being young?', 'words': [{'word': 'What', 'start': 17.374, 'end': 17.515, 'score': 0.989, 'speaker': 'SPEAKER_01'}, {'word': 'is', 'start': 17.595, 'end': 17.695, 'score': 0.501, 'speaker': 'SPEAKER_01'}, {'word': 'the', 'start': 17.735, 'end': 17.835, 'score': 0.919, 'speaker': 'SPEAKER_01'}, {'word': 'worst', 'start': 17.935, 'end': 18.195, 'score': 0.915, 'speaker': 'SPEAKER_01'}, {'word': 'thing', 'start': 18.235, 'end': 18.395, 'score': 0.721, 'speaker': 'SPEAKER_01'}, {'word': 'about', 'start': 18.435, 'end': 18.635, 'score': 0.863, 'speaker': 'SPEAKER_01'}, {'word': 'being', 'start': 18.675, 'end': 18.875, 'score': 0.62, 'speaker': 'SPEAKER_01'}, {'word': 'young?', 'start': 18.895, 'end': 19.116, 'score': 0.36, 'speaker': 'SPEAKER_01'}], 'speaker': 'SPEAKER_01'}, {'start': 20.656, 'end': 23.078, 'text': 'Well, you get lots of homework.', 'words': [{'word': 'Well,', 'start': 20.656, 'end': 20.977, 'score': 0.833, 'speaker': 'SPEAKER_00'}, {'word': 'you', 'start': 21.037, 'end': 21.217, 'score': 0.772, 'speaker': 'SPEAKER_00'}, {'word': 'ge ...

# %% [markdown]
# ## **7. Results**

# %% [markdown]
# ### Timestamp Format

# %%
result
# Out:
# {'segments': [{'start': 7.168,
#    'end': 7.568,
#    'text': " What's that?",
#    'words': [{'word': "What's",
#      'start': 7.168,
#      'end': 7.468,
#      'score': 0.296,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'that?',
#      'start': 7.488,
#      'end': 7.568,
#      'score': 0.122,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 7.588,
#    'end': 10.69,
#    'text': "I don't know where the question... I don't know where the song is.",
#    'words': [{'word': 'I',
#      'start': 7.588,
#      'end': 7.608,
#      'score': 0.002,
#      'speaker': 'SPEAKER_00'},
#     {'word': "don't",
#      'start': 7.628,
#      'end': 7.769,
#      'score': 0.771,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'know',
#      'start': 7.789,
#      'end': 7.929,
#      'score': 0.795,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'where',
#      'start': 7.949,
#      'end': 8.149,
#      'score': 0.576,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'the',
#      'start': 8.189,
#      'end': 8.349,
#      'score': 0.486,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'question...',
#      'start': 8.369,
#      'end': 9.049,
#      'score': 0.75,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 9.51,
#      'end': 9.57,
#      'score': 0.383,
#      'speaker': 'SPEAKER_00'},
#     {'word': "don't",
#      'start': 9.61,
#      'end': 9.73,
#      'score': 0.271,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'know',
#      'start': 9.75,
#      'end': 9.85,
#      'score': 0.162,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'where',
#      'start': 9.89,
#      'end': 10.07,
#      'score': 0.531,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'the',
#      'start': 10.09,
#      'end': 10.21,
#      'score': 0.122,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'song',
#      'start': 10.23,
#      'end': 10.45,
#      'score': 0.65,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'is.',
#      'start': 10.53,
#      'end': 10.69,
#      'score': 0.688,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 12.431,
#    'end': 13.592,
#    'text': 'Well, can I ask you a question?',
#    'words': [{'word': 'Well,',
#      'start': 12.431,
#      'end': 12.592,
#      'score': 0.483,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'can',
#      'start': 12.612,
#      'end': 12.752,
#      'score': 0.282,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'I',
#      'start': 12.772,
#      'end': 12.792,
#      'score': 0.092,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'ask',
#      'start': 12.832,
#      'end': 13.012,
#      'score': 0.736,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you',
#      'start': 13.032,
#      'end': 13.132,
#      'score': 0.889,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'a',
#      'start': 13.152,
#      'end': 13.172,
#      'score': 0.537,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'question?',
#      'start': 13.192,
#      'end': 13.592,
#      'score': 0.67,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 13.632,
#    'end': 14.132,
#    'text': 'The first one?',
#    'words': [{'word': 'The',
#      'start': 13.632,
#      'end': 13.712,
#      'score': 0.781,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'first',
#      'start': 13.732,
#      'end': 13.932,
#      'score': 0.877,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'one?',
#      'start': 14.012,
#      'end': 14.132,
#      'score': 0.856,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 16.014,
#    'end': 16.294,
#    'text': 'Right.',
#    'words': [{'word': 'Right.',
#      'start': 16.014,
#      'end': 16.294,
#      'score': 0.841,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 17.374,
#    'end': 19.116,
#    'text': 'What is the worst thing about being young?',
#    'words': [{'word': 'What',
#      'start': 17.374,
#      'end': 17.515,
#      'score': 0.989,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'is',
#      'start': 17.595,
#      'end': 17.695,
#      'score': 0.501,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'the',
#      'start': 17.735,
#      'end': 17.835,
#      'score': 0.919,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'worst',
#      'start': 17.935,
#      'end': 18.195,
#      'score': 0.915,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'thing',
#      'start': 18.235,
#      'end': 18.395,
#      'score': 0.721,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'about',
#      'start': 18.435,
#      'end': 18.635,
#      'score': 0.863,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'being',
#      'start': 18.675,
#      'end': 18.875,
#      'score': 0.62,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'young?',
#      'start': 18.895,
#      'end': 19.116,
#      'score': 0.36,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 20.656,
#    'end': 23.078,
#    'text': 'Well, you get lots of homework.',
#    'words': [{'word': 'Well,',
#      'start': 20.656,
#      'end': 20.977,
#      'score': 0.833,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'you',
#      'start': 21.037,
#      'end': 21.217,
#      'score': 0.772,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'get',
#      'start': 21.237,
#      'end': 21.457,
#      'score': 0.521,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'lots',
#      'start': 21.617,
#      'end': 22.057,
#      'score': 0.899,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'of',
#      'start': 22.157,
#      'end': 22.297,
#      'score': 0.83,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'homework.',
#      'start': 22.358,
#      'end': 23.078,
#      'score': 0.897,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 23.999,
#    'end': 28.421,
#    'text': "It's also pretty... It's... They're like in the middle.",
#    'words': [{'word': "It's",
#      'start': 23.999,
#      'end': 24.139,
#      'score': 0.896,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'also',
#      'start': 24.179,
#      'end': 24.499,
#      'score': 0.92,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'pretty...',
#      'start': 24.599,
#      'end': 24.899,
#      'score': 0.78,
#      'speaker': 'SPEAKER_00'},
#     {'word': "It's...",
#      'start': 25.499,
#      'end': 25.62,
#      'score': 0.557,
#      'speaker': 'SPEAKER_00'},
#     {'word': "They're",
#      'start': 25.98,
#      'end': 26.14,
#      'score': 0.21,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'like',
#      'start': 26.16,
#      'end': 26.42,
#      'score': 0.786,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'in',
#      'start': 27.621,
#      'end': 27.721,
#      'score': 0.946,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'the',
#      'start': 27.741,
#      'end': 27.961,
#      'score': 0.643,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'middle.',
#      'start': 28.041,
#      'end': 28.421,
#      'score': 0.733,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 28.902,
#    'end': 32.784,
#    'text': 'Like in school, like in the middle of bad and good.',
#    'words': [{'word': 'Like',
#      'start': 28.902,
#      'end': 30.162,
#      'score': 0.633,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'in',
#      'start': 30.262,
#      'end': 30.402,
#      'score': 0.584,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'school,',
#      'start': 30.422,
#      'end': 30.703,
#      'score': 0.636,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'like',
#      'start': 30.723,
#      'end': 30.903,
#      'score': 0.807,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'in',
#      'start': 30.963,
#      'end': 31.043,
#      'score': 0.827,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'the',
#      'start': 31.083,
#      'end': 31.163,
#      'score': 0.756,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'middle',
#      'start': 31.243,
#      'end': 31.543,
#      'score': 0.666,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'of',
#      'start': 31.583,
#      'end': 31.683,
#      'score': 0.784,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'bad',
#      'start': 32.063,
#      'end': 32.324,
#      'score': 0.741,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'and',
#      'start': 32.384,
#      'end': 32.504,
#      'score': 0.695,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'good.',
#      'start': 32.544,
#      'end': 32.784,
#      'score': 0.971,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 33.757,
#    'end': 35.719,
#    'text': ' What is the worst thing about being old?',
#    'words': [{'word': 'What',
#      'start': 33.757,
#      'end': 33.978,
#      'score': 0.699,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'is',
#      'start': 34.038,
#      'end': 34.118,
#      'score': 0.734,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'the',
#      'start': 34.138,
#      'end': 34.278,
#      'score': 0.859,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'worst',
#      'start': 34.298,
#      'end': 34.598,
#      'score': 0.813,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'thing',
#      'start': 34.638,
#      'end': 34.778,
#      'score': 0.421,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'about',
#      'start': 34.838,
#      'end': 35.098,
#      'score': 0.819,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'being',
#      'start': 35.118,
#      'end': 35.338,
#      'score': 0.846,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'old?',
#      'start': 35.519,
#      'end': 35.719,
#      'score': 0.798,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 38.02,
#    'end': 41.002,
#    'text': 'Not being able to do things that you could do when you were young.',
#    'words': [{'word': 'Not',
#      'start': 38.02,
#      'end': 38.18,
#      'score': 0.737,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'being',
#      'start': 38.22,
#      'end': 38.38,
#      'score': 0.88,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'able',
#      'start': 38.44,
#      'end': 38.621,
#      'score': 0.874,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'to',
#      'start': 38.661,
#      'end': 38.741,
#      'score': 0.982,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'do',
#      'start': 38.821,
#      'end': 38.961,
#      'score': 0.959,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'things',
#      'start': 39.061,
#      'end': 39.381,
#      'score': 0.724,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'that',
#      'start': 39.481,
#      'end': 39.621,
#      'score': 0.989,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you',
#      'start': 39.661,
#      'end': 39.781,
#      'score': 0.884,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'could',
#      'start': 39.801,
#      'end': 39.962,
#      'score': 0.876,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'do',
#      'start': 40.022,
#      'end': 40.202,
#      'score': 0.842,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'when',
#      'start': 40.262,
#      'end': 40.422,
#      'score': 0.797,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you',
#      'start': 40.442,
#      'end': 40.522,
#      'score': 0.974,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'were',
#      'start': 40.562,
#      'end': 40.702,
#      'score': 0.916,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'young.',
#      'start': 40.722,
#      'end': 41.002,
#      'score': 0.912,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 41.803,
#    'end': 46.106,
#    'text': "Like, you can't bend down and get stuff on the floor?",
#    'words': [{'word': 'Like,',
#      'start': 41.803,
#      'end': 42.203,
#      'score': 0.697,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'you',
#      'start': 43.304,
#      'end': 43.484,
#      'score': 0.903,
#      'speaker': 'SPEAKER_00'},
#     {'word': "can't",
#      'start': 43.524,
#      'end': 43.764,
#      'score': 0.607,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'bend',
#      'start': 43.824,
#      'end': 44.084,
#      'score': 0.668,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'down',
#      'start': 44.144,
#      'end': 44.425,
#      'score': 0.805,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'and',
#      'start': 44.485,
#      'end': 44.605,
#      'score': 0.55,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'get',
#      'start': 44.665,
#      'end': 44.925,
#      'score': 0.745,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'stuff',
#      'start': 44.945,
#      'end': 45.145,
#      'score': 0.29,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'on',
#      'start': 45.245,
#      'end': 45.365,
#      'score': 0.58,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'the',
#      'start': 45.385,
#      'end': 45.505,
#      'score': 0.365,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'floor?',
#      'start': 45.545,
#      'end': 46.106,
#      'score': 0.619,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 46.266,
#    'end': 47.567,
#    'text': 'Well, I can still do that.',
#    'words': [{'word': 'Well,',
#      'start': 46.266,
#      'end': 46.506,
#      'score': 0.926,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'I',
#      'start': 46.646,
#      'end': 46.686,
#      'score': 0.987,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'can',
#      'start': 46.726,
#      'end': 46.846,
#      'score': 0.996,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'still',
#      'start': 46.906,
#      'end': 47.146,
#      'score': 0.838,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'do',
#      'start': 47.186,
#      'end': 47.306,
#      'score': 0.845,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'that.',
#      'start': 47.366,
#      'end': 47.567,
#      'score': 0.833,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 47.907,
#    'end': 50.328,
#    'text': 'But the problem is your body gets a bit stiff.',
#    'words': [{'word': 'But',
#      'start': 47.907,
#      'end': 48.107,
#      'score': 0.834,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'the',
#      'start': 48.327,
#      'end': 48.447,
#      'score': 0.758,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'problem',
#      'start': 48.487,
#      'end': 48.827,
#      'score': 0.911,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'is',
#      'start': 48.928,
#      'end': 49.028,
#      'score': 0.862,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'your',
#      'start': 49.068,
#      'end': 49.208,
#      'score': 0.866,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'body',
#      'start': 49.248,
#      'end': 49.488,
#      'score': 0.935,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'gets',
#      'start': 49.528,
#      'end': 49.708,
#      'score': 0.844,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'a',
#      'start': 49.728,
#      'end': 49.748,
#      'score': 0.008,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'bit',
#      'start': 49.808,
#      'end': 49.968,
#      'score': 0.839,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'stiff.',
#      'start': 50.028,
#      'end': 50.328,
#      'score': 0.958,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 51.009,
#    'end': 54.111,
#    'text': 'I know it hurts a lot when you try to get down when you are old.',
#    'words': [{'word': 'I',
#      'start': 51.009,
#      'end': 51.069,
#      'score': 0.96,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'know',
#      'start': 51.109,
#      'end': 51.289,
#      'score': 0.779,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'it',
#      'start': 51.329,
#      'end': 51.389,
#      'score': 0.351,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'hurts',
#      'start': 51.449,
#      'end': 51.629,
#      'score': 0.468,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'a',
#      'start': 51.709,
#      'end': 51.91,
#      'score': 0.609,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'lot',
#      'start': 51.93,
#      'end': 52.07,
#      'score': 0.536,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'when',
#      'start': 52.09,
#      'end': 52.21,
#      'score': 0.388,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'you',
#      'start': 52.25,
#      'end': 52.33,
#      'score': 0.152,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'try',
#      'start': 52.35,
#      'end': 52.59,
#      'score': 0.287,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'to',
#      'start': 52.63,
#      'end': 52.67,
#      'score': 0.012,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'get',
#      'start': 52.69,
#      'end': 52.83,
#      'score': 0.423,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'down',
#      'start': 52.87,
#      'end': 53.11,
#      'score': 0.735,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'when',
#      'start': 53.15,
#      'end': 53.31,
#      'score': 0.41,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'you',
#      'start': 53.33,
#      'end': 53.451,
#      'score': 0.36,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'are',
#      'start': 53.671,
#      'end': 53.791,
#      'score': 0.26,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'old.',
#      'start': 54.011,
#      'end': 54.111,
#      'score': 0.307,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 54.131,
#    'end': 54.912,
#    'text': "That's right, yes.",
#    'words': [{'word': "That's",
#      'start': 54.131,
#      'end': 54.351,
#      'score': 0.718,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'right,',
#      'start': 54.391,
#      'end': 54.611,
#      'score': 0.837,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'yes.',
#      'start': 54.651,
#      'end': 54.912,
#      'score': 0.855,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 55.552,
#    'end': 57.253,
#    'text': 'You might get sick more often.',
#    'words': [{'word': 'You',
#      'start': 55.552,
#      'end': 55.652,
#      'score': 0.97,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'might',
#      'start': 55.692,
#      'end': 55.852,
#      'score': 0.827,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'get',
#      'start': 55.872,
#      'end': 56.052,
#      'score': 0.704,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'sick',
#      'start': 56.132,
#      'end': 56.352,
#      'score': 0.929,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'more',
#      'start': 56.693,
#      'end': 56.873,
#      'score': 0.88,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'often.',
#      'start': 56.973,
#      'end': 57.253,
#      'score': 0.883,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 58.494,
#    'end': 59.234,
#    'text': "Hopefully I don't.",
#    'words': [{'word': 'Hopefully',
#      'start': 58.494,
#      'end': 58.934,
#      'score': 0.39,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 58.954,
#      'end': 58.974,
#      'score': 0.0,
#      'speaker': 'SPEAKER_00'},
#     {'word': "don't.",
#      'start': 58.994,
#      'end': 59.234,
#      'score': 0.845,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 60.035,
#    'end': 60.715,
#    'text': "But that's the problem.",
#    'words': [{'word': 'But',
#      'start': 60.035,
#      'end': 60.155,
#      'score': 0.833,
#      'speaker': 'SPEAKER_01'},
#     {'word': "that's",
#      'start': 60.175,
#      'end': 60.355,
#      'score': 0.68,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'the',
#      'start': 60.375,
#      'end': 60.515,
#      'score': 0.458,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'problem.',
#      'start': 60.535,
#      'end': 60.715,
#      'score': 0.272,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 60.735,
#    'end': 61.476,
#    'text': "Yeah, that's pretty bad.",
#    'words': [{'word': 'Yeah,',
#      'start': 60.735,
#      'end': 60.815,
#      'score': 0.054,
#      'speaker': 'SPEAKER_00'},
#     {'word': "that's",
#      'start': 60.835,
#      'end': 60.976,
#      'score': 0.079,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'pretty',
#      'start': 60.996,
#      'end': 61.276,
#      'score': 0.692,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'bad.',
#      'start': 61.316,
#      'end': 61.476,
#      'score': 0.503,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 61.956,
#    'end': 62.737,
#    'text': 'It is pretty bad.',
#    'words': [{'word': 'It',
#      'start': 61.956,
#      'end': 62.036,
#      'score': 0.856,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'is',
#      'start': 62.116,
#      'end': 62.196,
#      'score': 0.652,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'pretty',
#      'start': 62.256,
#      'end': 62.477,
#      'score': 0.797,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'bad.',
#      'start': 62.517,
#      'end': 62.737,
#      'score': 0.997,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 63.331,
#    'end': 68.633,
#    'text': ' The only time I went to hospital is my mum to like get me born.',
#    'words': [{'word': 'The',
#      'start': 63.331,
#      'end': 63.451,
#      'score': 0.785,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'only',
#      'start': 63.531,
#      'end': 63.711,
#      'score': 0.771,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'time',
#      'start': 63.751,
#      'end': 63.951,
#      'score': 0.915,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 64.031,
#      'end': 64.111,
#      'score': 0.751,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'went',
#      'start': 64.151,
#      'end': 64.351,
#      'score': 0.771,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'to',
#      'start': 64.391,
#      'end': 64.571,
#      'score': 0.841,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'hospital',
#      'start': 64.871,
#      'end': 65.432,
#      'score': 0.577,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'is',
#      'start': 65.952,
#      'end': 66.052,
#      'score': 0.783,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'my',
#      'start': 66.092,
#      'end': 66.252,
#      'score': 0.895,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'mum',
#      'start': 66.292,
#      'end': 66.612,
#      'score': 0.765,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'to',
#      'start': 66.772,
#      'end': 66.992,
#      'score': 0.954,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'like',
#      'start': 67.092,
#      'end': 67.352,
#      'score': 0.859,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'get',
#      'start': 67.812,
#      'end': 68.012,
#      'score': 0.989,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'me',
#      'start': 68.072,
#      'end': 68.213,
#      'score': 0.964,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'born.',
#      'start': 68.273,
#      'end': 68.633,
#      'score': 0.824,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 68.653,
#    'end': 71.313,
#    'text': 'Do you wish you were old?',
#    'words': [{'word': 'Do',
#      'start': 68.653,
#      'end': 69.813,
#      'score': 0.764,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you',
#      'start': 69.853,
#      'end': 70.013,
#      'score': 0.834,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'wish',
#      'start': 70.033,
#      'end': 70.453,
#      'score': 0.677,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you',
#      'start': 70.493,
#      'end': 70.613,
#      'score': 0.88,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'were',
#      'start': 70.653,
#      'end': 70.773,
#      'score': 0.262,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'old?',
#      'start': 70.873,
#      'end': 71.313,
#      'score': 0.704,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 74.434,
#    'end': 84.918,
#    'text': 'Maybe, like so I was old and I so I can like buy stuff for my own and have be and have been married but that would be eww.',
#    'words': [{'word': 'Maybe,',
#      'start': 74.434,
#      'end': 74.995,
#      'score': 0.819,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'like',
#      'start': 75.875,
#      'end': 76.055,
#      'score': 0.847,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'so',
#      'start': 76.075,
#      'end': 76.115,
#      'score': 0.012,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 76.135,
#      'end': 76.155,
#      'score': 0.001,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'was',
#      'start': 76.215,
#      'end': 76.695,
#      'score': 0.729,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'old',
#      'start': 76.955,
#      'end': 77.195,
#      'score': 0.797,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'and',
#      'start': 77.375,
#      'end': 77.475,
#      'score': 0.948,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 77.595,
#      'end': 77.695,
#      'score': 0.652,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'so',
#      'start': 78.696,
#      'end': 78.836,
#      'score': 0.87,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 78.916,
#      'end': 78.956,
#      'score': 0.584,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'can',
#      'start': 78.976,
#      'end': 79.136,
#      'score': 0.879,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'like',
#      'start': 79.176,
#      'end': 79.416,
#      'score': 0.731,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'buy',
#      'start': 79.556,
#      'end': 79.936,
#      'score': 0.542,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'stuff',
#      'start': 79.956,
#      'end': 80.236,
#      'score': 0.654,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'for',
#      'start': 80.276,
#      'end': 80.396,
#      'score': 0.83,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'my',
#      'start': 80.456,
#      'end': 80.596,
#      'score': 0.996,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'own',
#      'start': 80.716,
#      'end': 80.856,
#      'score': 0.884,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'and',
#      'start': 80.936,
#      'end': 80.996,
#      'score': 0.972,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'have',
#      'start': 81.036,
#      'end': 81.216,
#      'score': 0.843,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'be',
#      'start': 81.356,
#      'end': 81.737,
#      'score': 0.826,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'and',
#      'start': 81.917,
#      'end': 81.997,
#      'score': 0.843,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'have',
#      'start': 82.057,
#      'end': 82.237,
#      'score': 0.918,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'been',
#      'start': 82.677,
#      'end': 82.917,
#      'score': 0.878,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'married',
#      'start': 82.997,
#      'end': 83.397,
#      'score': 0.898,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'but',
#      'start': 83.417,
#      'end': 83.517,
#      'score': 0.652,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'that',
#      'start': 83.537,
#      'end': 84.357,
#      'score': 0.378,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'would',
#      'start': 84.377,
#      'end': 84.517,
#      'score': 0.324,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'be',
#      'start': 84.537,
#      'end': 84.617,
#      'score': 0.255,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'eww.',
#      'start': 84.718,
#      'end': 84.918,
#      'score': 0.401,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 86.078,
#    'end': 87.898,
#    'text': 'Do you wish you were young?',
#    'words': [{'word': 'Do',
#      'start': 86.078,
#      'end': 86.238,
#      'score': 0.906,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'you',
#      'start': 86.298,
#      'end': 86.478,
#      'score': 0.878,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'wish',
#      'start': 86.598,
#      'end': 86.898,
#      'score': 0.826,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'you',
#      'start': 87.338,
#      'end': 87.518,
#      'score': 0.948,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'were',
#      'start': 87.578,
#      'end': 87.778,
#      'score': 0.85,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'young?',
#      'start': 87.798,
#      'end': 87.898,
#      'score': 0.041,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 87.918,
#    'end': 87.979,
#    'text': 'Why?',
#    'words': [{'word': 'Why?',
#      'start': 87.918,
#      'end': 87.979,
#      'score': 0.063,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 91.409,
#    'end': 95.573,
#    'text': ' Well, the problem about, the great thing about being young is you have more time.',
#    'words': [{'word': 'Well,',
#      'start': 91.409,
#      'end': 91.529,
#      'score': 0.222,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'the',
#      'start': 91.549,
#      'end': 91.629,
#      'score': 0.808,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'problem',
#      'start': 91.649,
#      'end': 91.97,
#      'score': 0.863,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'about,',
#      'start': 92.03,
#      'end': 92.33,
#      'score': 0.858,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'the',
#      'start': 92.73,
#      'end': 92.81,
#      'score': 0.838,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'great',
#      'start': 92.83,
#      'end': 92.951,
#      'score': 0.516,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'thing',
#      'start': 92.971,
#      'end': 93.111,
#      'score': 0.811,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'about',
#      'start': 93.151,
#      'end': 93.331,
#      'score': 0.991,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'being',
#      'start': 93.371,
#      'end': 93.551,
#      'score': 0.863,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'young',
#      'start': 93.591,
#      'end': 93.871,
#      'score': 0.763,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'is',
#      'start': 94.112,
#      'end': 94.232,
#      'score': 0.82,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you',
#      'start': 94.752,
#      'end': 94.872,
#      'score': 0.83,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'have',
#      'start': 94.912,
#      'end': 95.032,
#      'score': 0.868,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'more',
#      'start': 95.072,
#      'end': 95.252,
#      'score': 0.854,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'time.',
#      'start': 95.312,
#      'end': 95.573,
#      'score': 0.978,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 95.593,
#    'end': 97.454,
#    'text': 'You have more time to do things.',
#    'words': [{'word': 'You',
#      'start': 95.593,
#      'end': 95.653,
#      'score': 0.0,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'have',
#      'start': 96.353,
#      'end': 96.473,
#      'score': 0.178,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'more',
#      'start': 96.513,
#      'end': 96.634,
#      'score': 0.708,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'time',
#      'start': 96.674,
#      'end': 96.854,
#      'score': 0.863,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'to',
#      'start': 96.894,
#      'end': 96.974,
#      'score': 0.765,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'do',
#      'start': 97.014,
#      'end': 97.174,
#      'score': 0.904,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'things.',
#      'start': 97.214,
#      'end': 97.454,
#      'score': 0.9,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 98.015,
#    'end': 100.637,
#    'text': 'I could play games, which I did.',
#    'words': [{'word': 'I',
#      'start': 98.015,
#      'end': 98.095,
#      'score': 0.767,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'could',
#      'start': 98.135,
#      'end': 98.315,
#      'score': 0.823,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'play',
#      'start': 98.455,
#      'end': 98.715,
#      'score': 0.812,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'games,',
#      'start': 98.755,
#      'end': 99.276,
#      'score': 0.846,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'which',
#      'start': 100.116,
#      'end': 100.277,
#      'score': 0.937,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'I',
#      'start': 100.357,
#      'end': 100.417,
#      'score': 0.787,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'did.',
#      'start': 100.457,
#      'end': 100.637,
#      'score': 0.887,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 101.077,
#    'end': 102.578,
#    'text': 'I used to play cowboys and Indians.',
#    'words': [{'word': 'I',
#      'start': 101.077,
#      'end': 101.137,
#      'score': 0.807,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'used',
#      'start': 101.197,
#      'end': 101.317,
#      'score': 0.869,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'to',
#      'start': 101.357,
#      'end': 101.417,
#      'score': 0.785,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'play',
#      'start': 101.458,
#      'end': 101.618,
#      'score': 0.853,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'cowboys',
#      'start': 101.658,
#      'end': 102.078,
#      'score': 0.857,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'and',
#      'start': 102.118,
#      'end': 102.198,
#      'score': 0.768,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'Indians.',
#      'start': 102.238,
#      'end': 102.578,
#      'score': 0.838,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 103.019,
#    'end': 104.1,
#    'text': "Yeah, that's what I play.",
#    'words': [{'word': 'Yeah,',
#      'start': 103.019,
#      'end': 103.199,
#      'score': 0.442,
#      'speaker': 'SPEAKER_00'},
#     {'word': "that's",
#      'start': 103.239,
#      'end': 103.419,
#      'score': 0.208,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'what',
#      'start': 103.459,
#      'end': 103.579,
#      'score': 0.258,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 103.679,
#      'end': 103.799,
#      'score': 0.792,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'play.',
#      'start': 103.859,
#      'end': 104.1,
#      'score': 0.356,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 104.36,
#    'end': 104.68,
#    'text': 'Do you?',
#    'words': [{'word': 'Do',
#      'start': 104.36,
#      'end': 104.48,
#      'score': 0.99,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you?',
#      'start': 104.52,
#      'end': 104.68,
#      'score': 0.914,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 104.7,
#    'end': 105.141,
#    'text': 'Yeah.',
#    'words': [{'word': 'Yeah.',
#      'start': 104.7,
#      'end': 105.141,
#      'score': 0.43,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 105.761,
#    'end': 107.142,
#    'text': "That's what I like about being young.",
#    'words': [{'word': "That's",
#      'start': 105.761,
#      'end': 105.961,
#      'score': 0.849,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'what',
#      'start': 105.981,
#      'end': 106.121,
#      'score': 0.778,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'I',
#      'start': 106.141,
#      'end': 106.181,
#      'score': 0.5,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'like',
#      'start': 106.221,
#      'end': 106.402,
#      'score': 0.762,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'about',
#      'start': 106.442,
#      'end': 106.622,
#      'score': 0.958,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'being',
#      'start': 106.662,
#      'end': 106.822,
#      'score': 0.907,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'young.',
#      'start': 106.862,
#      'end': 107.142,
#      'score': 0.866,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 108.003,
#    'end': 109.524,
#    'text': 'I could use my imagination more.',
#    'words': [{'word': 'I',
#      'start': 108.003,
#      'end': 108.063,
#      'score': 0.754,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'could',
#      'start': 108.083,
#      'end': 108.223,
#      'score': 0.929,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'use',
#      'start': 108.343,
#      'end': 108.463,
#      'score': 0.791,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'my',
#      'start': 108.483,
#      'end': 108.603,
#      'score': 0.675,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'imagination',
#      'start': 108.663,
#      'end': 109.304,
#      'score': 0.928,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'more.',
#      'start': 109.344,
#      'end': 109.524,
#      'score': 0.797,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 110.345,
#    'end': 111.566,
#    'text': "That's a sad story.",
#    'words': [{'word': "That's",
#      'start': 110.345,
#      'end': 110.645,
#      'score': 0.865,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'a',
#      'start': 110.665,
#      'end': 110.685,
#      'score': 0.0,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'sad',
#      'start': 110.725,
#      'end': 110.985,
#      'score': 0.711,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'story.',
#      'start': 111.085,
#      'end': 111.566,
#      'score': 0.883,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 111.586,
#    'end': 113.127,
#    'text': "You can't do that anymore.",
#    'words': [{'word': 'You',
#      'start': 111.586,
#      'end': 111.646,
#      'score': 0.0,
#      'speaker': 'SPEAKER_00'},
#     {'word': "can't",
#      'start': 112.326,
#      'end': 112.527,
#      'score': 0.45,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'do',
#      'start': 112.567,
#      'end': 112.707,
#      'score': 0.612,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'that',
#      'start': 112.727,
#      'end': 112.827,
#      'score': 0.138,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'anymore.',
#      'start': 112.867,
#      'end': 113.127,
#      'score': 0.242,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 113.607,
#    'end': 116.09,
#    'text': 'Well, I could be an older cowboy.',
#    'words': [{'word': 'Well,',
#      'start': 113.607,
#      'end': 113.948,
#      'score': 0.938,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 114.448,
#      'end': 114.508,
#      'score': 0.886,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'could',
#      'start': 114.528,
#      'end': 114.668,
#      'score': 0.98,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'be',
#      'start': 114.708,
#      'end': 114.849,
#      'score': 0.829,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'an',
#      'start': 114.869,
#      'end': 114.929,
#      'score': 0.445,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'older',
#      'start': 115.469,
#      'end': 115.669,
#      'score': 0.912,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'cowboy.',
#      'start': 115.709,
#      'end': 116.09,
#      'score': 0.892,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 116.11,
#    'end': 117.711,
#    'text': 'I might do it yet.',
#    'words': [{'word': 'I',
#      'start': 116.11,
#      'end': 116.13,
#      'score': 0.0,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'might',
#      'start': 117.03,
#      'end': 117.23,
#      'score': 0.319,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'do',
#      'start': 117.25,
#      'end': 117.371,
#      'score': 0.794,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'it',
#      'start': 117.411,
#      'end': 117.491,
#      'score': 0.509,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'yet.',
#      'start': 117.511,
#      'end': 117.711,
#      'score': 0.681,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 119.012,
#    'end': 120.073,
#    'text': 'Will you fall in love?',
#    'words': [{'word': 'Will',
#      'start': 119.012,
#      'end': 119.192,
#      'score': 0.782,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you',
#      'start': 119.212,
#      'end': 119.352,
#      'score': 0.789,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'fall',
#      'start': 119.412,
#      'end': 119.692,
#      'score': 0.876,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'in',
#      'start': 119.733,
#      'end': 119.813,
#      'score': 0.828,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'love?',
#      'start': 119.873,
#      'end': 120.073,
#      'score': 0.893,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 121.556,
#    'end': 122.617,
#    'text': ' And what will it be like?',
#    'words': [{'word': 'And',
#      'start': 121.556,
#      'end': 121.676,
#      'score': 0.789,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'what',
#      'start': 121.756,
#      'end': 121.936,
#      'score': 0.91,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'will',
#      'start': 121.956,
#      'end': 122.116,
#      'score': 0.865,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'it',
#      'start': 122.156,
#      'end': 122.216,
#      'score': 0.763,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'be',
#      'start': 122.256,
#      'end': 122.376,
#      'score': 0.847,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'like?',
#      'start': 122.416,
#      'end': 122.617,
#      'score': 0.863,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 123.577,
#    'end': 124.217,
#    'text': "I don't know.",
#    'words': [{'word': 'I',
#      'start': 123.577,
#      'end': 123.637,
#      'score': 0.687,
#      'speaker': 'SPEAKER_00'},
#     {'word': "don't",
#      'start': 123.677,
#      'end': 123.897,
#      'score': 0.854,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'know.',
#      'start': 123.977,
#      'end': 124.217,
#      'score': 0.771,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 124.658,
#    'end': 126.419,
#    'text': "Like, we'll have babies.",
#    'words': [{'word': 'Like,',
#      'start': 124.658,
#      'end': 124.878,
#      'score': 0.765,
#      'speaker': 'SPEAKER_00'},
#     {'word': "we'll",
#      'start': 125.538,
#      'end': 125.698,
#      'score': 0.391,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'have',
#      'start': 125.738,
#      'end': 125.918,
#      'score': 0.256,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'babies.',
#      'start': 125.998,
#      'end': 126.419,
#      'score': 0.713,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 126.519,
#    'end': 127.599,
#    'text': "It'll be, like, fun.",
#    'words': [{'word': "It'll",
#      'start': 126.519,
#      'end': 126.759,
#      'score': 0.738,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'be,',
#      'start': 126.799,
#      'end': 126.879,
#      'score': 0.996,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'like,',
#      'start': 126.939,
#      'end': 127.099,
#      'score': 0.832,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'fun.',
#      'start': 127.179,
#      'end': 127.599,
#      'score': 0.789,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 127.719,
#    'end': 129.2,
#    'text': "I'll, like, have to change.",
#    'words': [{'word': "I'll,",
#      'start': 127.719,
#      'end': 127.899,
#      'score': 0.348,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'like,',
#      'start': 127.919,
#      'end': 128.179,
#      'score': 0.514,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'have',
#      'start': 128.219,
#      'end': 128.46,
#      'score': 0.604,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'to',
#      'start': 128.5,
#      'end': 128.66,
#      'score': 0.914,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'change.',
#      'start': 128.8,
#      'end': 129.2,
#      'score': 0.686,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 129.68,
#    'end': 131.461,
#    'text': "Even though I'll have to change his diaper.",
#    'words': [{'word': 'Even',
#      'start': 129.68,
#      'end': 129.94,
#      'score': 0.771,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'though',
#      'start': 129.96,
#      'end': 130.2,
#      'score': 0.412,
#      'speaker': 'SPEAKER_00'},
#     {'word': "I'll",
#      'start': 130.301,
#      'end': 130.421,
#      'score': 0.236,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'have',
#      'start': 130.461,
#      'end': 130.621,
#      'score': 0.449,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'to',
#      'start': 130.641,
#      'end': 130.741,
#      'score': 0.846,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'change',
#      'start': 130.781,
#      'end': 131.021,
#      'score': 0.889,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'his',
#      'start': 131.061,
#      'end': 131.161,
#      'score': 0.806,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'diaper.',
#      'start': 131.201,
#      'end': 131.461,
#      'score': 0.5,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 132.101,
#    'end': 132.842,
#    'text': "It'll be fun.",
#    'words': [{'word': "It'll",
#      'start': 132.101,
#      'end': 132.302,
#      'score': 0.891,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'be',
#      'start': 132.342,
#      'end': 132.442,
#      'score': 0.978,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'fun.',
#      'start': 132.582,
#      'end': 132.842,
#      'score': 0.953,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 133.442,
#    'end': 133.602,
#    'text': 'Ah.',
#    'words': [{'word': 'Ah.',
#      'start': 133.442,
#      'end': 133.602,
#      'score': 0.716,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 134.223,
#    'end': 135.383,
#    'text': 'But what if he cries?',
#    'words': [{'word': 'But',
#      'start': 134.223,
#      'end': 134.363,
#      'score': 0.89,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'what',
#      'start': 134.383,
#      'end': 134.563,
#      'score': 0.801,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'if',
#      'start': 134.643,
#      'end': 134.763,
#      'score': 0.472,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'he',
#      'start': 134.803,
#      'end': 134.883,
#      'score': 0.569,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'cries?',
#      'start': 134.923,
#      'end': 135.383,
#      'score': 0.782,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 135.983,
#    'end': 139.545,
#    'text': "Ah, well... I'll just sing, like, Ed Sheeran to him, like... Hmm?",
#    'words': [{'word': 'Ah,',
#      'start': 135.983,
#      'end': 136.204,
#      'score': 0.777,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'well...',
#      'start': 136.284,
#      'end': 136.584,
#      'score': 0.896,
#      'speaker': 'SPEAKER_01'},
#     {'word': "I'll",
#      'start': 137.024,
#      'end': 137.104,
#      'score': 0.102,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'just',
#      'start': 137.124,
#      'end': 137.304,
#      'score': 0.464,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'sing,',
#      'start': 137.324,
#      'end': 137.444,
#      'score': 0.256,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'like,',
#      'start': 137.484,
#      'end': 137.664,
#      'score': 0.806,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'Ed',
#      'start': 137.784,
#      'end': 137.944,
#      'score': 0.715,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'Sheeran',
#      'start': 138.004,
#      'end': 138.425,
#      'score': 0.577,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'to',
#      'start': 138.445,
#      'end': 138.545,
#      'score': 0.725,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'him,',
#      'start': 138.605,
#      'end': 138.705,
#      'score': 0.241,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'like...',
#      'start': 138.725,
#      'end': 138.965,
#      'score': 0.549,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'Hmm?',
#      'start': 139.345,
#      'end': 139.545,
#      'score': 0.55,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 140.646,
#    'end': 141.906,
#    'text': 'And who do you love now?',
#    'words': [{'word': 'And',
#      'start': 140.646,
#      'end': 140.726,
#      'score': 0.896,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'who',
#      'start': 140.786,
#      'end': 140.906,
#      'score': 0.814,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'do',
#      'start': 140.926,
#      'end': 140.966,
#      'score': 0.568,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you',
#      'start': 140.986,
#      'end': 141.086,
#      'score': 0.798,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'love',
#      'start': 141.146,
#      'end': 141.326,
#      'score': 0.639,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'now?',
#      'start': 141.626,
#      'end': 141.906,
#      'score': 0.909,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 142.147,
#    'end': 142.947,
#    'text': 'Who do you love now?',
#    'words': [{'word': 'Who',
#      'start': 142.147,
#      'end': 142.247,
#      'score': 0.356,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'do',
#      'start': 142.267,
#      'end': 142.307,
#      'score': 0.243,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'you',
#      'start': 142.327,
#      'end': 142.427,
#      'score': 0.694,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'love',
#      'start': 142.467,
#      'end': 142.627,
#      'score': 0.682,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'now?',
#      'start': 142.707,
#      'end': 142.947,
#      'score': 0.829,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 144.288,
#    'end': 144.508,
#    'text': 'Um... Hmm?',
#    'words': [{'word': 'Um...',
#      'start': 144.288,
#      'end': 144.328,
#      'score': 0.157,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'Hmm?',
#      'start': 144.348,
#      'end': 144.508,
#      'score': 0.45,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 148.83,
#    'end': 149.25,
#    'text': 'My mom.',
#    'words': [{'word': 'My',
#      'start': 148.83,
#      'end': 148.99,
#      'score': 0.764,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'mom.',
#      'start': 149.01,
#      'end': 149.25,
#      'score': 0.741,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 149.49,
#    'end': 149.911,
#    'text': 'Your mom?',
#    'words': [{'word': 'Your',
#      'start': 149.49,
#      'end': 149.63,
#      'score': 0.9,
#      'speaker': 'SPEAKER_01'},
#     {'word': 'mom?',
#      'start': 149.67,
#      'end': 149.911,
#      'score': 0.743,
#      'speaker': 'SPEAKER_01'}],
#    'speaker': 'SPEAKER_01'},
#   {'start': 150.111,
#    'end': 150.411,
#    'text': 'Your dad?',
# ...
#    'start': 203.421,
#    'end': 203.761,
#    'score': 0.719,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'I',
#    'start': 203.861,
#    'end': 203.921,
#    'score': 0.703,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'would',
#    'start': 203.941,
#    'end': 204.101,
#    'score': 0.668,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'give',
#    'start': 204.141,
#    'end': 204.361,
#    'score': 0.81,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'to',
#    'start': 204.382,
#    'end': 204.422,
#    'score': 0.841,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'you,',
#    'start': 204.482,
#    'end': 204.662,
#    'score': 0.661,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'Sean,',
#    'start': 204.722,
#    'end': 205.042,
#    'score': 0.742,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'is',
#    'start': 206.782,
#    'end': 206.942,
#    'score': 0.97,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'you',
#    'start': 207.563,
#    'end': 207.663,
#    'score': 0.825,
#    'speaker': 'SPEAKER_01'},
#   {'word': "don't",
#    'start': 207.683,
#    'end': 207.823,
#    'score': 0.873,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'have',
#    'start': 207.863,
#    'end': 207.963,
#    'score': 0.874,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'to',
#    'start': 207.983,
#    'end': 208.023,
#    'score': 0.974,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'be',
#    'start': 208.063,
#    'end': 208.143,
#    'score': 0.777,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'rich',
#    'start': 208.203,
#    'end': 208.443,
#    'score': 0.794,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'to',
#    'start': 209.403,
#    'end': 209.503,
#    'score': 0.8,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'be',
#    'start': 209.543,
#    'end': 209.623,
#    'score': 0.814,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'happy.',
#    'start': 209.683,
#    'end': 209.943,
#    'score': 0.926,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'Do',
#    'start': 210.784,
#    'end': 210.904,
#    'score': 0.965,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'the',
#    'start': 210.944,
#    'end': 211.024,
#    'score': 0.856,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'things',
#    'start': 211.044,
#    'end': 211.204,
#    'score': 0.99,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'you',
#    'start': 211.224,
#    'end': 211.344,
#    'score': 0.819,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'like',
#    'start': 211.384,
#    'end': 211.564,
#    'score': 0.774,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'doing',
#    'start': 211.604,
#    'end': 211.804,
#    'score': 0.907,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'that',
#    'start': 211.844,
#    'end': 211.984,
#    'score': 0.91,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'make',
#    'start': 212.024,
#    'end': 212.164,
#    'score': 0.948,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'you',
#    'start': 212.184,
#    'end': 212.284,
#    'score': 0.978,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'feel',
#    'start': 212.324,
#    'end': 212.524,
#    'score': 0.598,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'good.',
#    'start': 212.584,
#    'end': 212.804,
#    'score': 0.849,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'Because',
#    'start': 213.945,
#    'end': 214.145,
#    'score': 0.999,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'when',
#    'start': 214.185,
#    'end': 214.265,
#    'score': 0.931,
#    'speaker': 'SPEAKER_01'},
#   {'word': "you're",
#    'start': 214.285,
#    'end': 214.445,
#    'score': 0.751,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'happy',
#    'start': 214.465,
#    'end': 214.685,
#    'score': 0.938,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'yourself,',
#    'start': 214.725,
#    'end': 215.185,
#    'score': 0.795,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'everybody',
#    'start': 215.685,
#    'end': 216.085,
#    'score': 0.851,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'else',
#    'start': 216.145,
#    'end': 216.285,
#    'score': 0.912,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'is',
#    'start': 216.365,
#    'end': 216.425,
#    'score': 0.752,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'happy.',
#    'start': 216.465,
#    'end': 216.706,
#    'score': 0.888,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'Sean,',
#    'start': 218.406,
#    'end': 218.566,
#    'score': 0.516,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'do',
#    'start': 218.586,
#    'end': 218.686,
#    'score': 0.488,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'you',
#    'start': 218.746,
#    'end': 218.846,
#    'score': 0.309,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'have',
#    'start': 218.866,
#    'end': 218.946,
#    'score': 0.008,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'advice',
#    'start': 218.966,
#    'end': 219.286,
#    'score': 0.643,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'for',
#    'start': 219.326,
#    'end': 219.566,
#    'score': 0.726,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'Dad?',
#    'start': 220.147,
#    'end': 220.387,
#    'score': 0.727,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'To',
#    'start': 221.187,
#    'end': 221.667,
#    'score': 0.778,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'act',
#    'start': 222.247,
#    'end': 222.407,
#    'score': 0.73,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'normal,',
#    'start': 222.808,
#    'end': 223.468,
#    'score': 0.646,
#    'speaker': 'SPEAKER_00'},
#   {'word': "don't",
#    'start': 223.828,
#    'end': 224.068,
#    'score': 0.814,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'be',
#    'start': 224.108,
#    'end': 224.268,
#    'score': 0.918,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'silly,',
#    'start': 224.388,
#    'end': 224.828,
#    'score': 0.549,
#    'speaker': 'SPEAKER_00'},
#   {'word': "don't",
#    'start': 224.908,
#    'end': 225.128,
#    'score': 0.445,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'bully',
#    'start': 225.208,
#    'end': 225.608,
#    'score': 0.676,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'lots',
#    'start': 225.648,
#    'end': 225.849,
#    'score': 0.52,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'of',
#    'start': 225.929,
#    'end': 226.029,
#    'score': 0.508,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'people.',
#    'start': 226.049,
#    'end': 226.469,
#    'score': 0.842,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'The',
#    'start': 227.269,
#    'end': 227.389,
#    'score': 0.886,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'people',
#    'start': 227.429,
#    'end': 227.749,
#    'score': 0.785,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'I',
#    'start': 227.849,
#    'end': 227.929,
#    'score': 0.814,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'know',
#    'start': 227.949,
#    'end': 228.109,
#    'score': 0.775,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'in',
#    'start': 228.149,
#    'end': 228.269,
#    'score': 0.613,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'school,',
#    'start': 228.289,
#    'end': 228.569,
#    'score': 0.396,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'like',
#    'start': 228.629,
#    'end': 228.809,
#    'score': 0.907,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'my',
#    'start': 228.87,
#    'end': 229.05,
#    'score': 0.866,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'friend',
#    'start': 229.09,
#    'end': 229.29,
#    'score': 0.354,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'Alex',
#    'start': 229.49,
#    'end': 229.67,
#    'score': 0.656,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'in',
#    'start': 229.71,
#    'end': 229.91,
#    'score': 0.657,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'school,',
#    'start': 229.93,
#    'end': 230.19,
#    'score': 0.42,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'Whenever',
#    'start': 230.908,
#    'end': 231.288,
#    'score': 0.67,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'he',
#    'start': 231.308,
#    'end': 231.388,
#    'score': 0.494,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'gets',
#    'start': 231.428,
#    'end': 231.749,
#    'score': 0.843,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'hurt,',
#    'start': 231.909,
#    'end': 232.189,
#    'score': 0.517,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'I',
#    'start': 232.349,
#    'end': 232.449,
#    'score': 0.872,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'hug',
#    'start': 232.509,
#    'end': 232.749,
#    'score': 0.711,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'him.',
#    'start': 232.81,
#    'end': 232.99,
#    'score': 0.493,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'He',
#    'start': 233.73,
#    'end': 233.83,
#    'score': 0.369,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'might',
#    'start': 233.89,
#    'end': 234.151,
#    'score': 0.377,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'not',
#    'start': 234.211,
#    'end': 234.391,
#    'score': 0.888,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'be',
#    'start': 234.431,
#    'end': 234.591,
#    'score': 0.674,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'able',
#    'start': 234.611,
#    'end': 234.811,
#    'score': 0.458,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'to',
#    'start': 234.831,
#    'end': 234.911,
#    'score': 0.322,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'work,',
#    'start': 234.971,
#    'end': 235.171,
#    'score': 0.435,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'but...',
#    'start': 235.271,
#    'end': 235.552,
#    'score': 0.707,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'No,',
#    'start': 236.252,
#    'end': 236.492,
#    'score': 0.697,
#    'speaker': 'SPEAKER_01'},
#   {'word': "that's",
#    'start': 236.512,
#    'end': 236.693,
#    'score': 0.822,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'good',
#    'start': 236.773,
#    'end': 236.933,
#    'score': 0.862,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'advice.',
#    'start': 236.973,
#    'end': 237.353,
#    'score': 0.857,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'And',
#    'start': 238.974,
#    'end': 239.154,
#    'score': 0.538,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'be',
#    'start': 239.575,
#    'end': 239.795,
#    'score': 0.978,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'yourself.',
#    'start': 239.955,
#    'end': 240.455,
#    'score': 0.817,
#    'speaker': 'SPEAKER_01'},
#   {'word': "Don't",
#    'start': 240.816,
#    'end': 240.996,
#    'score': 0.82,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'let',
#    'start': 241.056,
#    'end': 241.176,
#    'score': 0.871,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'other',
#    'start': 241.216,
#    'end': 241.416,
#    'score': 0.669,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'people',
#    'start': 241.456,
#    'end': 241.756,
#    'score': 0.857,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'tell',
#    'start': 241.816,
#    'end': 241.977,
#    'score': 0.995,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'you',
#    'start': 242.017,
#    'end': 242.137,
#    'score': 0.752,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'what',
#    'start': 242.217,
#    'end': 242.337,
#    'score': 0.992,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'you',
#    'start': 242.377,
#    'end': 242.497,
#    'score': 0.769,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'should',
#    'start': 242.517,
#    'end': 242.717,
#    'score': 0.862,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'be.',
#    'start': 242.777,
#    'end': 242.997,
#    'score': 0.521,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'Just',
#    'start': 244.058,
#    'end': 244.258,
#    'score': 0.96,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'be',
#    'start': 244.378,
#    'end': 244.539,
#    'score': 0.947,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'as',
#    'start': 244.599,
#    'end': 244.679,
#    'score': 0.846,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'you',
#    'start': 244.699,
#    'end': 244.819,
#    'score': 0.866,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'are.',
#    'start': 244.899,
#    'end': 245.039,
#    'score': 0.658,
#    'speaker': 'SPEAKER_01'},
#   {'word': "Isn't",
#    'start': 245.199,
#    'end': 245.339,
#    'score': 0.619,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'that',
#    'start': 245.359,
#    'end': 245.519,
#    'score': 0.844,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'true?',
#    'start': 245.539,
#    'end': 245.759,
#    'score': 0.737,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'Yeah.',
#    'start': 246.18,
#    'end': 246.48,
#    'score': 0.665,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'And',
#    'start': 246.58,
#    'end': 246.68,
#    'score': 0.776,
#    'speaker': 'SPEAKER_00'},
#   {'word': "I'm",
#    'start': 246.8,
#    'end': 246.94,
#    'score': 0.816,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'sure',
#    'start': 247.0,
#    'end': 247.201,
#    'score': 0.708,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'your',
#    'start': 247.761,
#    'end': 247.901,
#    'score': 0.909,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'life',
#    'start': 247.921,
#    'end': 248.081,
#    'score': 0.823,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'is',
#    'start': 248.141,
#    'end': 248.201,
#    'score': 0.75,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'going',
#    'start': 248.221,
#    'end': 248.362,
#    'score': 0.811,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'to',
#    'start': 248.382,
#    'end': 248.422,
#    'score': 0.984,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'be',
#    'start': 248.442,
#    'end': 248.522,
#    'score': 0.601,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'very',
#    'start': 248.562,
#    'end': 248.742,
#    'score': 0.734,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'successful.',
#    'start': 248.782,
#    'end': 249.322,
#    'score': 0.847,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'You',
#    'start': 250.964,
#    'end': 251.084,
#    'score': 0.995,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'have',
#    'start': 251.124,
#    'end': 251.244,
#    'score': 0.955,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'all',
#    'start': 251.304,
#    'end': 251.464,
#    'score': 0.849,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'the',
#    'start': 251.504,
#    'end': 251.564,
#    'score': 0.968,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'right',
#    'start': 251.624,
#    'end': 251.804,
#    'score': 0.877,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'things.',
#    'start': 251.864,
#    'end': 252.104,
#    'score': 0.859,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'You',
#    'start': 252.545,
#    'end': 252.645,
#    'score': 0.958,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'have',
#    'start': 252.665,
#    'end': 252.785,
#    'score': 0.836,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'all',
#    'start': 252.845,
#    'end': 252.985,
#    'score': 0.771,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'the',
#    'start': 253.025,
#    'end': 253.085,
#    'score': 0.958,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'right',
#    'start': 253.145,
#    'end': 253.285,
#    'score': 0.914,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'things',
#    'start': 253.325,
#    'end': 253.545,
#    'score': 0.756,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'to',
#    'start': 253.586,
#    'end': 253.686,
#    'score': 0.758,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'do.',
#    'start': 253.726,
#    'end': 253.926,
#    'score': 0.804,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'All',
#    'start': 254.566,
#    'end': 254.686,
#    'score': 0.879,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'your',
#    'start': 254.706,
#    'end': 254.846,
#    'score': 0.724,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'good',
#    'start': 254.867,
#    'end': 254.987,
#    'score': 0.886,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'friends.',
#    'start': 255.047,
#    'end': 255.367,
#    'score': 0.742,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'And',
#    'start': 256.448,
#    'end': 256.728,
#    'score': 0.827,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'keep',
#    'start': 256.888,
#    'end': 257.108,
#    'score': 0.939,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'those',
#    'start': 257.128,
#    'end': 257.348,
#    'score': 0.84,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'friends',
#    'start': 257.388,
#    'end': 257.649,
#    'score': 0.674,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'going.',
#    'start': 257.689,
#    'end': 257.949,
#    'score': 0.801,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'And',
#    'start': 258.509,
#    'end': 258.609,
#    'score': 0.931,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'keep',
#    'start': 258.669,
#    'end': 258.87,
#    'score': 0.899,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'life',
#    'start': 258.91,
#    'end': 259.11,
#    'score': 0.88,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'going.',
#    'start': 259.15,
#    'end': 259.41,
#    'score': 0.822,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'Oops.',
#    'start': 259.55,
#    'end': 259.75,
#    'score': 0.503,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'There',
#    'start': 260.251,
#    'end': 260.391,
#    'score': 0.197,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'you',
#    'start': 260.411,
#    'end': 260.491,
#    'score': 0.8,
#    'speaker': 'SPEAKER_01'},
#   {'word': 'go.',
#    'start': 260.531,
#    'end': 260.591,
#    'score': 0.744,
#    'speaker': 'SPEAKER_01'}]}

# %% [markdown]
# ### Conversational Format

# %%
import re

# Format the output
conversation = []  # List to hold the formatted conversation
for segment in result["segments"]:
    speaker_id_str = segment["speaker"]  # Get the speaker ID as a string
    text = segment["text"].strip()        # Get the transcribed text and strip whitespace

    # Extract the numeric part of the speaker ID (e.g., from 'SPEAKER_01' to '1')
    speaker_id_match = re.search(r'(\d+)', speaker_id_str)
    if speaker_id_match:
        speaker_id = int(speaker_id_match.group(1))  # Convert the extracted number to an integer
    else:
        continue  # Skip this segment if no valid speaker ID is found

    # Create a speaker label (e.g., Speaker A, Speaker B)
    speaker_label = f"Speaker {chr(65 + speaker_id)}"  # Converts 0 -> 'A', 1 -> 'B', etc.

    # Append the formatted text to the conversation list
    conversation.append(f"{speaker_label}: {text}")

# Print the formatted conversation
for line in conversation:
    print(line)
# Out:
# Speaker B: What's that?
# Speaker A: I don't know where the question... I don't know where the song is.
# Speaker B: Well, can I ask you a question?
# Speaker B: The first one?
# Speaker B: Right.
# Speaker B: What is the worst thing about being young?
# Speaker A: Well, you get lots of homework.
# Speaker A: It's also pretty... It's... They're like in the middle.
# Speaker A: Like in school, like in the middle of bad and good.
# Speaker A: What is the worst thing about being old?
# Speaker B: Not being able to do things that you could do when you were young.
# Speaker A: Like, you can't bend down and get stuff on the floor?
# Speaker B: Well, I can still do that.
# Speaker B: But the problem is your body gets a bit stiff.
# Speaker A: I know it hurts a lot when you try to get down when you are old.
# Speaker B: That's right, yes.
# Speaker B: You might get sick more often.
# Speaker B: Hopefully I don't.
# Speaker B: But that's the problem.
# Speaker A: Yeah, that's pretty bad.
# Speaker B: It is pretty bad.
# Speaker A: The only time I went to hospital is my mum to like get me born.
# Speaker B: Do you wish you were old?
# Speaker A: Maybe, like so I was old and I so I can like buy stuff for my own and have be and have been married but that would be eww.
# Speaker A: Do you wish you were young?
# Speaker A: Why?
# Speaker B: Well, the problem about, the great thing about being young is you have more time.
# Speaker B: You have more time to do things.
# Speaker B: I could play games, which I did.
# Speaker B: I used to play cowboys and Indians.
# Speaker A: Yeah, that's what I play.
# Speaker B: Do you?
# Speaker B: Yeah.
# Speaker B: That's what I like about being young.
# Speaker B: I could use my imagination more.
# Speaker A: That's a sad story.
# Speaker A: You can't do that anymore.
# Speaker B: Well, I could be an older cowboy.
# Speaker B: I might do it yet.
# Speaker B: Will you fall in love?
# Speaker B: And what will it be like?
# Speaker A: I don't know.
# Speaker A: Like, we'll have babies.
# Speaker A: It'll be, like, fun.
# Speaker A: I'll, like, have to change.
# Speaker A: Even though I'll have to change his diaper.
# Speaker A: It'll be fun.
# Speaker B: Ah.
# Speaker A: But what if he cries?
# Speaker A: Ah, well... I'll just sing, like, Ed Sheeran to him, like... Hmm?
# Speaker B: And who do you love now?
# Speaker B: Who do you love now?
# Speaker A: Um... Hmm?
# Speaker A: My mom.
# Speaker B: Your mom?
# Speaker B: Your dad?
# Speaker A: I like my family.
# Speaker A: Did you fall in love?
# Speaker A: What was it like?
# Speaker B: Yes.
# Speaker B: It was different for me.
# Speaker B: I fell in love late.
# Speaker A: And did you get married?
# Speaker B: No, unfortunately.
# Speaker B: My partner, she passed away.
# Speaker B: She died, unfortunately.
# Speaker B: That was a sad thing.
# Speaker B: Yeah, she got sick.
# Speaker A: I'm gonna cry.
# Speaker B: No, no, no.
# Speaker B: Don't.
# Speaker B: No, no, no.
# Speaker B: No.
# Speaker B: Ah, no, no.
# Speaker B: These things happen, Sian.
# Speaker B: That's life.
# Speaker B: But... I have very good memories.
# Speaker B: Very good memories.
# Speaker B: And you live... A lot of the time, you live in your head with memories.
# Speaker B: You can remember all the good things, and that's the important thing.
# Speaker B: Well, the advice I would give to you, Sean, is you don't have to be rich to be happy.
# Speaker B: Do the things you like doing that make you feel good.
# Speaker B: Because when you're happy yourself, everybody else is happy.
# Speaker B: Sean, do you have advice for Dad?
# Speaker A: To act normal, don't be silly, don't bully lots of people.
# Speaker A: The people I know in school, like my friend Alex in school,
# Speaker A: Whenever he gets hurt, I hug him.
# Speaker A: He might not be able to work, but... No, that's good advice.
# Speaker B: And be yourself.
# Speaker B: Don't let other people tell you what you should be.
# Speaker B: Just be as you are.
# Speaker B: Isn't that true?
# Speaker A: Yeah.
# Speaker B: And I'm sure your life is going to be very successful.
# Speaker B: You have all the right things.
# Speaker B: You have all the right things to do.
# Speaker B: All your good friends.
# Speaker B: And keep those friends going.
# Speaker B: And keep life going.
# Speaker B: Oops.
# Speaker B: There you go.
